# %%
# !pip install -r requirements.txt
# Out:
# Collecting streamlit (from -r requirements.txt (line 1))
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\bhavy\\Desktop\\Projects\\python-based-projects\\9_movie-recommender-system\\venv\\Lib\\site-packages\\streamlit-1.41.1.dist-info\\RECORD8gpgluyl.tmp' -> 'C:\\Users\\bhavy\\Desktop\\Projects\\python-based-projects\\9_movie-recommender-system\\venv\\Lib\\site-packages\\streamlit-1.41.1.dist-info\\RECORD'
# Check the permissions.
#
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Using cached streamlit-1.41.1-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting dvc_s3 (from -r requirements.txt (line 2))
#   Using cached dvc_s3-3.2.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting pandas (from -r requirements.txt (line 3))
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy (from -r requirements.txt (line 4))
#   Using cached numpy-2.2.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting python-dotenv (from -r requirements.txt (line 5))
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting scikit-learn (from -r requirements.txt (line 6))
#   Using cached scikit_learn-1.6.0-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Collecting mlflow (from -r requirements.txt (line 7))
#   Using cached mlflow-2.19.0-py3-none-any.whl.metadata (30 kB)
# Collecting dagshub (from -r requirements.txt (line 8))
#   Using cached dagshub-0.4.0-py3-none-any.whl.metadata (11 kB)
# Collecting nltk (from -r requirements.txt (line 9))
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting altair<6,>=4.0 (from streamlit->-r requirements.txt (line 1))
#   Using cached altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit->-r requirements.txt (line 1))
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<6,>=4.0 (from streamlit->-r requirements.txt (line 1))
#   Using cached cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting click<9,>=7.0 (from streamlit->-r requirements.txt (line 1))
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: packaging<25,>=20 in c:\users\bhavy\desktop\projects\python-based-projects\9_movie-recommender-system\venv\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (24.2)
# Collecting pillow<12,>=7.1.0 (from streamlit->-r requirements.txt (line 1))
#   Using cached pillow-11.0.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting protobuf<6,>=3.20 (from streamlit->-r requirements.txt (line 1))
#   Using cached protobuf-5.29.2-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Collecting pyarrow>=7.0 (from streamlit->-r requirements.txt (line 1))
#   Using cached pyarrow-18.1.0-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Collecting requests<3,>=2.27 (from streamlit->-r requirements.txt (line 1))
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting rich<14,>=10.14.0 (from streamlit->-r requirements.txt (line 1))
#   Using cached rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting tenacity<10,>=8.1.0 (from streamlit->-r requirements.txt (line 1))
#   Using cached tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting toml<2,>=0.10.1 (from streamlit->-r requirements.txt (line 1))
#   Using cached toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-extensions<5,>=4.3.0 (from streamlit->-r requirements.txt (line 1))
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting watchdog<7,>=2.1.5 (from streamlit->-r requirements.txt (line 1))
#   Using cached watchdog-6.0.0-py3-none-win_amd64.whl.metadata (44 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit->-r requirements.txt (line 1))
#   Using cached GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit->-r requirements.txt (line 1))
#   Using cached pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\bhavy\desktop\projects\python-based-projects\9_movie-recommender-system\venv\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (6.4.2)
# Collecting dvc (from dvc_s3->-r requirements.txt (line 2))
#   Using cached dvc-3.58.0-py3-none-any.whl.metadata (18 kB)
# Collecting s3fs>=2023.6.0 (from dvc_s3->-r requirements.txt (line 2))
#   Using cached s3fs-2024.12.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting aiobotocore>=2.5.0 (from aiobotocore[boto3]>=2.5.0->dvc_s3->-r requirements.txt (line 2))
#   Using cached aiobotocore-2.16.0-py3-none-any.whl.metadata (23 kB)
# Collecting flatten-dict<1,>=0.4.1 (from dvc_s3->-r requirements.txt (line 2))
#   Using cached flatten_dict-0.4.2-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bhavy\desktop\projects\python-based-projects\9_movie-recommender-system\venv\lib\site-packages (from pandas->-r requirements.txt (line 3)) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->-r requirements.txt (line 3))
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->-r requirements.txt (line 3))
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting scipy>=1.6.0 (from scikit-learn->-r requirements.txt (line 6))
#   Using cached scipy-1.14.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn->-r requirements.txt (line 6))
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->-r requirements.txt (line 6))
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting mlflow-skinny==2.19.0 (from mlflow->-r requirements.txt (line 7))
#   Using cached mlflow_skinny-2.19.0-py3-none-any.whl.metadata (31 kB)
# Collecting Flask<4 (from mlflow->-r requirements.txt (line 7))
#   Using cached flask-3.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting Jinja2<4,>=3.0 (from mlflow->-r requirements.txt (line 7))
#   Using cached jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# Collecting alembic!=1.10.0,<2 (from mlflow->-r requirements.txt (line 7))
#   Using cached alembic-1.14.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting docker<8,>=4.0.0 (from mlflow->-r requirements.txt (line 7))
#   Using cached docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow->-r requirements.txt (line 7))
#   Using cached graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting markdown<4,>=3.3 (from mlflow->-r requirements.txt (line 7))
#   Using cached Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Collecting matplotlib<4 (from mlflow->-r requirements.txt (line 7))
#   Using cached matplotlib-3.10.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting sqlalchemy<3,>=1.4.0 (from mlflow->-r requirements.txt (line 7))
#   Using cached SQLAlchemy-2.0.36-cp312-cp312-win_amd64.whl.metadata (9.9 kB)
# Collecting waitress<4 (from mlflow->-r requirements.txt (line 7))
#   Using cached waitress-3.0.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting cloudpickle<4 (from mlflow-skinny==2.19.0->mlflow->-r requirements.txt (line 7))
#   Using cached cloudpickle-3.1.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==2.19.0->mlflow->-r requirements.txt (line 7))
#   Using cached databricks_sdk-0.40.0-py3-none-any.whl.metadata (38 kB)
# Collecting importlib_metadata!=4.7.0,<9,>=3.7.0 (from mlflow-skinny==2.19.0->mlflow->-r requirements.txt (line 7))
#   Using cached importlib_metadata-8.5.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==2.19.0->mlflow->-r requirements.txt (line 7))
#   Using cached opentelemetry_api-1.29.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==2.19.0->mlflow->-r requirements.txt (line 7))
#   Using cached opentelemetry_sdk-1.29.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting pyyaml<7,>=5.1 (from mlflow-skinny==2.19.0->mlflow->-r requirements.txt (line 7))
#   Using cached PyYAML-6.0.2-cp312-cp312-win_amd64.whl.metadata (2.1 kB)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==2.19.0->mlflow->-r requirements.txt (line 7))
#   Using cached sqlparse-0.5.3-py3-none-any.whl.metadata (3.9 kB)
# Collecting appdirs>=1.4.4 (from dagshub->-r requirements.txt (line 8))
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting httpx>=0.23.0 (from dagshub->-r requirements.txt (line 8))
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting dacite~=1.6.0 (from dagshub->-r requirements.txt (line 8))
#   Using cached dacite-1.6.0-py3-none-any.whl.metadata (14 kB)
# Collecting gql[requests] (from dagshub->-r requirements.txt (line 8))
#   Using cached gql-3.5.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting dataclasses-json (from dagshub->-r requirements.txt (line 8))
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting treelib>=1.6.4 (from dagshub->-r requirements.txt (line 8))
#   Using cached treelib-1.7.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting pathvalidate>=3.0.0 (from dagshub->-r requirements.txt (line 8))
#   Using cached pathvalidate-3.2.1-py3-none-any.whl.metadata (12 kB)
# Collecting boto3 (from dagshub->-r requirements.txt (line 8))
#   Using cached boto3-1.35.86-py3-none-any.whl.metadata (6.7 kB)
# Collecting dagshub-annotation-converter>=0.1.0 (from dagshub->-r requirements.txt (line 8))
#   Using cached dagshub_annotation_converter-0.1.2-py3-none-any.whl.metadata (2.5 kB)
# Collecting regex>=2021.8.3 (from nltk->-r requirements.txt (line 9))
#   Using cached regex-2024.11.6-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk->-r requirements.txt (line 9))
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting botocore<1.35.82,>=1.35.74 (from aiobotocore>=2.5.0->aiobotocore[boto3]>=2.5.0->dvc_s3->-r requirements.txt (line 2))
#   Using cached botocore-1.35.81-py3-none-any.whl.metadata (5.7 kB)
# Collecting aiohttp<4.0.0,>=3.9.2 (from aiobotocore>=2.5.0->aiobotocore[boto3]>=2.5.0->dvc_s3->-r requirements.txt (line 2))
#   Using cached aiohttp-3.11.11-cp312-cp312-win_amd64.whl.metadata (8.0 kB)
# Collecting wrapt<2.0.0,>=1.10.10 (from aiobotocore>=2.5.0->aiobotocore[boto3]>=2.5.0->dvc_s3->-r requirements.txt (line 2))
#   Using cached wrapt-1.17.0-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Collecting aioitertools<1.0.0,>=0.5.1 (from aiobotocore>=2.5.0->aiobotocore[boto3]>=2.5.0->dvc_s3->-r requirements.txt (line 2))
#   Using cached aioitertools-0.12.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting boto3 (from dagshub->-r requirements.txt (line 8))
#   Using cached boto3-1.35.81-py3-none-any.whl.metadata (6.7 kB)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow->-r requirements.txt (line 7))
#   Using cached Mako-1.3.8-py3-none-any.whl.metadata (2.9 kB)
# Collecting jsonschema>=3.0 (from altair<6,>=4.0->streamlit->-r requirements.txt (line 1))
#   Using cached jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting narwhals>=1.14.2 (from altair<6,>=4.0->streamlit->-r requirements.txt (line 1))
#   Using cached narwhals-1.19.0-py3-none-any.whl.metadata (9.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->dagshub->-r requirements.txt (line 8))
#   Using cached jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3->dagshub->-r requirements.txt (line 8))
#   Using cached s3transfer-0.10.4-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: colorama in c:\users\bhavy\desktop\projects\python-based-projects\9_movie-recommender-system\venv\lib\site-packages (from click<9,>=7.0->streamlit->-r requirements.txt (line 1)) (0.4.6)
# Collecting lxml (from dagshub-annotation-converter>=0.1.0->dagshub->-r requirements.txt (line 8))
#   Using cached lxml-5.3.0-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Collecting pydantic>=2.0.0 (from dagshub-annotation-converter>=0.1.0->dagshub->-r requirements.txt (line 8))
#   Using cached pydantic-2.10.4-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: pywin32>=304 in c:\users\bhavy\desktop\projects\python-based-projects\9_movie-recommender-system\venv\lib\site-packages (from docker<8,>=4.0.0->mlflow->-r requirements.txt (line 7)) (308)
# Collecting urllib3>=1.26.0 (from docker<8,>=4.0.0->mlflow->-r requirements.txt (line 7))
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting Werkzeug>=3.1 (from Flask<4->mlflow->-r requirements.txt (line 7))
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting itsdangerous>=2.2 (from Flask<4->mlflow->-r requirements.txt (line 7))
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: six<2.0,>=1.12 in c:\users\bhavy\desktop\projects\python-based-projects\9_movie-recommender-system\venv\lib\site-packages (from flatten-dict<1,>=0.4.1->dvc_s3->-r requirements.txt (line 2)) (1.17.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 1))
#   Using cached gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow->-r requirements.txt (line 7))
#   Using cached graphql_core-3.2.5-py3-none-any.whl.metadata (10 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow->-r requirements.txt (line 7))
#   Using cached graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Collecting anyio (from httpx>=0.23.0->dagshub->-r requirements.txt (line 8))
#   Using cached anyio-4.7.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting certifi (from httpx>=0.23.0->dagshub->-r requirements.txt (line 8))
#   Using cached certifi-2024.12.14-py3-none-any.whl.metadata (2.3 kB)
# Collecting httpcore==1.* (from httpx>=0.23.0->dagshub->-r requirements.txt (line 8))
#   Using cached httpcore-1.0.7-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx>=0.23.0->dagshub->-r requirements.txt (line 8))
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.23.0->dagshub->-r requirements.txt (line 8))
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting MarkupSafe>=2.0 (from Jinja2<4,>=3.0->mlflow->-r requirements.txt (line 7))
#   Using cached MarkupSafe-3.0.2-cp312-cp312-win_amd64.whl.metadata (4.1 kB)
# Collecting contourpy>=1.0.1 (from matplotlib<4->mlflow->-r requirements.txt (line 7))
#   Using cached contourpy-1.3.1-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib<4->mlflow->-r requirements.txt (line 7))
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib<4->mlflow->-r requirements.txt (line 7))
#   Using cached fonttools-4.55.3-cp312-cp312-win_amd64.whl.metadata (168 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib<4->mlflow->-r requirements.txt (line 7))
#   Using cached kiwisolver-1.4.7-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib<4->mlflow->-r requirements.txt (line 7))
#   Using cached pyparsing-3.2.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2.27->streamlit->-r requirements.txt (line 1))
#   Using cached charset_normalizer-3.4.0-cp312-cp312-win_amd64.whl.metadata (34 kB)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=10.14.0->streamlit->-r requirements.txt (line 1))
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\bhavy\desktop\projects\python-based-projects\9_movie-recommender-system\venv\lib\site-packages (from rich<14,>=10.14.0->streamlit->-r requirements.txt (line 1)) (2.18.0)
# Collecting fsspec==2024.12.0.* (from s3fs>=2023.6.0->dvc_s3->-r requirements.txt (line 2))
#   Using cached fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Collecting greenlet!=0.4.17 (from sqlalchemy<3,>=1.4.0->mlflow->-r requirements.txt (line 7))
#   Using cached greenlet-3.1.1-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->dagshub->-r requirements.txt (line 8))
#   Using cached marshmallow-3.23.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json->dagshub->-r requirements.txt (line 8))
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting attrs>=22.2.0 (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached attrs-24.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting celery (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached celery-5.4.0-py3-none-any.whl.metadata (21 kB)
# Collecting configobj>=5.0.9 (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached configobj-5.0.9-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting distro>=1.3 (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting dpath<3,>=2.1.0 (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached dpath-2.2.0-py3-none-any.whl.metadata (15 kB)
# Collecting dulwich (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached dulwich-0.22.7-cp312-cp312-win_amd64.whl.metadata (4.5 kB)
# Collecting dvc-data<3.17,>=3.16.2 (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached dvc_data-3.16.7-py3-none-any.whl.metadata (5.1 kB)
# Collecting dvc-http>=2.29.0 (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached dvc_http-2.32.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting dvc-objects (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached dvc_objects-5.1.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting dvc-render<2,>=1.0.1 (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached dvc_render-1.0.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting dvc-studio-client<1,>=0.21 (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached dvc_studio_client-0.21.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting dvc-task<1,>=0.3.0 (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached dvc_task-0.40.2-py3-none-any.whl.metadata (10.0 kB)
# Collecting flufl.lock<9,>=8.1.0 (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached flufl_lock-8.1.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting funcy>=1.14 (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached funcy-2.0-py2.py3-none-any.whl.metadata (5.9 kB)
# Collecting grandalf<1,>=0.7 (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached grandalf-0.8-py3-none-any.whl.metadata (1.7 kB)
# Collecting gto<2,>=1.6.0 (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached gto-1.7.2-py3-none-any.whl.metadata (4.7 kB)
# Collecting hydra-core>=1.1 (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting iterative-telemetry>=0.0.7 (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached iterative_telemetry-0.0.9-py3-none-any.whl.metadata (4.1 kB)
# Collecting kombu (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached kombu-5.4.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting networkx>=2.5 (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting omegaconf (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting pathspec>=0.10.3 (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: platformdirs<5,>=3.1.1 in c:\users\bhavy\desktop\projects\python-based-projects\9_movie-recommender-system\venv\lib\site-packages (from dvc->dvc_s3->-r requirements.txt (line 2)) (4.3.6)
# Requirement already satisfied: psutil>=5.8 in c:\users\bhavy\desktop\projects\python-based-projects\9_movie-recommender-system\venv\lib\site-packages (from dvc->dvc_s3->-r requirements.txt (line 2)) (6.1.1)
# Collecting pydot>=1.2.4 (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached pydot-3.0.3-py3-none-any.whl.metadata (10 kB)
# Collecting pygtrie>=2.3.2 (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached pygtrie-2.5.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting ruamel.yaml>=0.17.11 (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached ruamel.yaml-0.18.6-py3-none-any.whl.metadata (23 kB)
# Collecting scmrepo<4,>=3.3.8 (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached scmrepo-3.3.9-py3-none-any.whl.metadata (4.8 kB)
# Collecting shortuuid>=0.5 (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached shortuuid-1.0.13-py3-none-any.whl.metadata (5.8 kB)
# Collecting shtab<2,>=1.3.4 (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached shtab-1.7.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting tabulate>=0.8.7 (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting tomlkit>=0.11.1 (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting voluptuous>=0.11.7 (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached voluptuous-0.15.2-py3-none-any.whl.metadata (20 kB)
# Collecting zc.lockfile>=1.2.1 (from dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached zc.lockfile-3.0.post1-py3-none-any.whl.metadata (6.2 kB)
# Collecting yarl<2.0,>=1.6 (from gql[requests]->dagshub->-r requirements.txt (line 8))
#   Using cached yarl-1.18.3-cp312-cp312-win_amd64.whl.metadata (71 kB)
# Collecting backoff<3.0,>=1.11.1 (from gql[requests]->dagshub->-r requirements.txt (line 8))
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting requests-toolbelt<2,>=1.0.0 (from gql[requests]->dagshub->-r requirements.txt (line 8))
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.9.2->aiobotocore>=2.5.0->aiobotocore[boto3]>=2.5.0->dvc_s3->-r requirements.txt (line 2))
#   Using cached aiohappyeyeballs-2.4.4-py3-none-any.whl.metadata (6.1 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.9.2->aiobotocore>=2.5.0->aiobotocore[boto3]>=2.5.0->dvc_s3->-r requirements.txt (line 2))
#   Using cached aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.9.2->aiobotocore>=2.5.0->aiobotocore[boto3]>=2.5.0->dvc_s3->-r requirements.txt (line 2))
#   Using cached frozenlist-1.5.0-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.9.2->aiobotocore>=2.5.0->aiobotocore[boto3]>=2.5.0->dvc_s3->-r requirements.txt (line 2))
#   Using cached multidict-6.1.0-cp312-cp312-win_amd64.whl.metadata (5.1 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.9.2->aiobotocore>=2.5.0->aiobotocore[boto3]>=2.5.0->dvc_s3->-r requirements.txt (line 2))
#   Using cached propcache-0.2.1-cp312-cp312-win_amd64.whl.metadata (9.5 kB)
# Collecting sniffio>=1.1 (from anyio->httpx>=0.23.0->dagshub->-r requirements.txt (line 8))
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.19.0->mlflow->-r requirements.txt (line 7))
#   Using cached google_auth-2.37.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting dictdiffer>=0.8.1 (from dvc-data<3.17,>=3.16.2->dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached dictdiffer-0.9.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting diskcache>=5.2.1 (from dvc-data<3.17,>=3.16.2->dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Collecting sqltrie<1,>=0.11.0 (from dvc-data<3.17,>=3.16.2->dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached sqltrie-0.11.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting orjson<4,>=3 (from dvc-data<3.17,>=3.16.2->dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached orjson-3.10.12-cp312-none-win_amd64.whl.metadata (42 kB)
# Collecting aiohttp-retry>=2.5.0 (from dvc-http>=2.29.0->dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached aiohttp_retry-2.9.1-py3-none-any.whl.metadata (8.8 kB)
# Collecting billiard<5.0,>=4.2.0 (from celery->dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached billiard-4.2.1-py3-none-any.whl.metadata (4.4 kB)
# Collecting vine<6.0,>=5.1.0 (from celery->dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached vine-5.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting click-didyoumean>=0.3.0 (from celery->dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached click_didyoumean-0.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting click-repl>=0.2.0 (from celery->dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached click_repl-0.3.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting click-plugins>=1.1.1 (from celery->dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Collecting atpublic (from flufl.lock<9,>=8.1.0->dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached atpublic-5.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 1))
#   Using cached smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting entrypoints (from gto<2,>=1.6.0->dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached entrypoints-0.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting semver>=2.13.0 (from gto<2,>=1.6.0->dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached semver-3.0.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting typer>=0.4.1 (from gto<2,>=1.6.0->dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached typer-0.15.1-py3-none-any.whl.metadata (15 kB)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.1->dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached antlr4_python3_runtime-4.9.3-py3-none-any.whl
# Collecting zipp>=3.20 (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.19.0->mlflow->-r requirements.txt (line 7))
#   Using cached zipp-3.21.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting filelock (from iterative-telemetry>=0.0.7->dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 1))
#   Using cached jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 1))
#   Using cached referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 1))
#   Using cached rpds_py-0.22.3-cp312-cp312-win_amd64.whl.metadata (4.2 kB)
# Collecting amqp<6.0.0,>=5.1.1 (from kombu->dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached amqp-5.3.1-py3-none-any.whl.metadata (8.9 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->-r requirements.txt (line 1))
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting deprecated>=1.2.6 (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.19.0->mlflow->-r requirements.txt (line 7))
#   Using cached Deprecated-1.2.15-py2.py3-none-any.whl.metadata (5.5 kB)
# Collecting opentelemetry-semantic-conventions==0.50b0 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.19.0->mlflow->-r requirements.txt (line 7))
#   Using cached opentelemetry_semantic_conventions-0.50b0-py3-none-any.whl.metadata (2.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.0.0->dagshub-annotation-converter>=0.1.0->dagshub->-r requirements.txt (line 8))
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.2 (from pydantic>=2.0.0->dagshub-annotation-converter>=0.1.0->dagshub->-r requirements.txt (line 8))
#   Using cached pydantic_core-2.27.2-cp312-cp312-win_amd64.whl.metadata (6.7 kB)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.11->dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached ruamel.yaml.clib-0.2.12-cp312-cp312-win_amd64.whl.metadata (2.8 kB)
# Collecting pygit2>=1.14.0 (from scmrepo<4,>=3.3.8->dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached pygit2-1.16.0-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Collecting asyncssh<3,>=2.13.1 (from scmrepo<4,>=3.3.8->dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached asyncssh-2.19.0-py3-none-any.whl.metadata (9.9 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json->dagshub->-r requirements.txt (line 8))
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting setuptools (from zc.lockfile>=1.2.1->dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached setuptools-75.6.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting cryptography>=39.0 (from asyncssh<3,>=2.13.1->scmrepo<4,>=3.3.8->dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached cryptography-44.0.0-cp39-abi3-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: prompt-toolkit>=3.0.36 in c:\users\bhavy\desktop\projects\python-based-projects\9_movie-recommender-system\venv\lib\site-packages (from click-repl>=0.2.0->celery->dvc->dvc_s3->-r requirements.txt (line 2)) (3.0.48)
# Collecting pyasn1-modules>=0.2.1 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.19.0->mlflow->-r requirements.txt (line 7))
#   Using cached pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.19.0->mlflow->-r requirements.txt (line 7))
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting cffi>=1.17.0 (from pygit2>=1.14.0->scmrepo<4,>=3.3.8->dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached cffi-1.17.1-cp312-cp312-win_amd64.whl.metadata (1.6 kB)
# Collecting shellingham>=1.3.0 (from typer>=0.4.1->gto<2,>=1.6.0->dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting pycparser (from cffi>=1.17.0->pygit2>=1.14.0->scmrepo<4,>=3.3.8->dvc->dvc_s3->-r requirements.txt (line 2))
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: wcwidth in c:\users\bhavy\desktop\projects\python-based-projects\9_movie-recommender-system\venv\lib\site-packages (from prompt-toolkit>=3.0.36->click-repl>=0.2.0->celery->dvc->dvc_s3->-r requirements.txt (line 2)) (0.2.13)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.19.0->mlflow->-r requirements.txt (line 7))
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Using cached streamlit-1.41.1-py2.py3-none-any.whl (9.1 MB)
# Using cached dvc_s3-3.2.0-py3-none-any.whl (13 kB)
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached numpy-2.2.1-cp312-cp312-win_amd64.whl (12.6 MB)
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Using cached scikit_learn-1.6.0-cp312-cp312-win_amd64.whl (11.1 MB)
# Using cached mlflow-2.19.0-py3-none-any.whl (27.4 MB)
# Using cached mlflow_skinny-2.19.0-py3-none-any.whl (5.9 MB)
# Using cached dagshub-0.4.0-py3-none-any.whl (254 kB)
# Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# Using cached aiobotocore-2.16.0-py3-none-any.whl (77 kB)
# Using cached alembic-1.14.0-py3-none-any.whl (233 kB)
# Using cached altair-5.5.0-py3-none-any.whl (731 kB)
# Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached boto3-1.35.81-py3-none-any.whl (139 kB)
# Using cached cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Using cached dacite-1.6.0-py3-none-any.whl (12 kB)
# Using cached dagshub_annotation_converter-0.1.2-py3-none-any.whl (33 kB)
# Using cached docker-7.1.0-py3-none-any.whl (147 kB)
# Using cached flask-3.1.0-py3-none-any.whl (102 kB)
# Using cached flatten_dict-0.4.2-py2.py3-none-any.whl (9.7 kB)
# Using cached GitPython-3.1.43-py3-none-any.whl (207 kB)
# Using cached graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.7-py3-none-any.whl (78 kB)
# Using cached jinja2-3.1.5-py3-none-any.whl (134 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached Markdown-3.7-py3-none-any.whl (106 kB)
# Using cached matplotlib-3.10.0-cp312-cp312-win_amd64.whl (8.0 MB)
# Using cached pathvalidate-3.2.1-py3-none-any.whl (23 kB)
# Using cached pillow-11.0.0-cp312-cp312-win_amd64.whl (2.6 MB)
# Using cached protobuf-5.29.2-cp310-abi3-win_amd64.whl (434 kB)
# Using cached pyarrow-18.1.0-cp312-cp312-win_amd64.whl (25.1 MB)
# Using cached pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached PyYAML-6.0.2-cp312-cp312-win_amd64.whl (156 kB)
# Using cached regex-2024.11.6-cp312-cp312-win_amd64.whl (273 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached rich-13.9.4-py3-none-any.whl (242 kB)
# Using cached s3fs-2024.12.0-py3-none-any.whl (30 kB)
# Using cached fsspec-2024.12.0-py3-none-any.whl (183 kB)
# Using cached scipy-1.14.1-cp312-cp312-win_amd64.whl (44.5 MB)
# Using cached SQLAlchemy-2.0.36-cp312-cp312-win_amd64.whl (2.1 MB)
# Using cached tenacity-9.0.0-py3-none-any.whl (28 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Using cached treelib-1.7.0-py3-none-any.whl (18 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Using cached waitress-3.0.2-py3-none-any.whl (56 kB)
# Using cached watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached dvc-3.58.0-py3-none-any.whl (457 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached aiohttp-3.11.11-cp312-cp312-win_amd64.whl (437 kB)
# Using cached aioitertools-0.12.0-py3-none-any.whl (24 kB)
# Using cached anyio-4.7.0-py3-none-any.whl (93 kB)
# Using cached attrs-24.3.0-py3-none-any.whl (63 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached botocore-1.35.81-py3-none-any.whl (13.3 MB)
# Using cached certifi-2024.12.14-py3-none-any.whl (164 kB)
# Using cached charset_normalizer-3.4.0-cp312-cp312-win_amd64.whl (102 kB)
# Using cached cloudpickle-3.1.0-py3-none-any.whl (22 kB)
# Using cached configobj-5.0.9-py2.py3-none-any.whl (35 kB)
# Using cached contourpy-1.3.1-cp312-cp312-win_amd64.whl (220 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached databricks_sdk-0.40.0-py3-none-any.whl (629 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached dpath-2.2.0-py3-none-any.whl (17 kB)
# Using cached dvc_data-3.16.7-py3-none-any.whl (78 kB)
# Using cached dvc_http-2.32.0-py3-none-any.whl (12 kB)
# Using cached dvc_objects-5.1.0-py3-none-any.whl (33 kB)
# Using cached dvc_render-1.0.2-py3-none-any.whl (22 kB)
# Using cached dvc_studio_client-0.21.0-py3-none-any.whl (16 kB)
# Using cached dvc_task-0.40.2-py3-none-any.whl (21 kB)
# Using cached celery-5.4.0-py3-none-any.whl (425 kB)
# Using cached flufl_lock-8.1.0-py3-none-any.whl (11 kB)
# Using cached fonttools-4.55.3-cp312-cp312-win_amd64.whl (2.2 MB)
# Using cached funcy-2.0-py2.py3-none-any.whl (30 kB)
# Using cached gitdb-4.0.11-py3-none-any.whl (62 kB)
# Using cached grandalf-0.8-py3-none-any.whl (41 kB)
# Using cached graphql_core-3.2.5-py3-none-any.whl (203 kB)
# Using cached graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Using cached greenlet-3.1.1-cp312-cp312-win_amd64.whl (299 kB)
# Using cached gto-1.7.2-py3-none-any.whl (45 kB)
# Using cached hydra_core-1.3.2-py3-none-any.whl (154 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached importlib_metadata-8.5.0-py3-none-any.whl (26 kB)
# Using cached iterative_telemetry-0.0.9-py3-none-any.whl (10 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Using cached jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Using cached kiwisolver-1.4.7-cp312-cp312-win_amd64.whl (55 kB)
# Using cached kombu-5.4.2-py3-none-any.whl (201 kB)
# Using cached vine-5.1.0-py3-none-any.whl (9.6 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached MarkupSafe-3.0.2-cp312-cp312-win_amd64.whl (15 kB)
# Using cached marshmallow-3.23.2-py3-none-any.whl (49 kB)
# Using cached narwhals-1.19.0-py3-none-any.whl (256 kB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Using cached omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Using cached opentelemetry_api-1.29.0-py3-none-any.whl (64 kB)
# Using cached opentelemetry_sdk-1.29.0-py3-none-any.whl (118 kB)
# Using cached opentelemetry_semantic_conventions-0.50b0-py3-none-any.whl (166 kB)
# Using cached pathspec-0.12.1-py3-none-any.whl (31 kB)
# Using cached pydantic-2.10.4-py3-none-any.whl (431 kB)
# Using cached pydantic_core-2.27.2-cp312-cp312-win_amd64.whl (2.0 MB)
# Using cached pydot-3.0.3-py3-none-any.whl (35 kB)
# Using cached pygtrie-2.5.0-py3-none-any.whl (25 kB)
# Using cached pyparsing-3.2.0-py3-none-any.whl (106 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached ruamel.yaml-0.18.6-py3-none-any.whl (117 kB)
# Using cached s3transfer-0.10.4-py3-none-any.whl (83 kB)
# Using cached scmrepo-3.3.9-py3-none-any.whl (74 kB)
# Using cached dulwich-0.22.7-cp312-cp312-win_amd64.whl (599 kB)
# Using cached shortuuid-1.0.13-py3-none-any.whl (10 kB)
# Using cached shtab-1.7.1-py3-none-any.whl (14 kB)
# Using cached sqlparse-0.5.3-py3-none-any.whl (44 kB)
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Using cached tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
# Using cached voluptuous-0.15.2-py3-none-any.whl (31 kB)
# Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Using cached wrapt-1.17.0-cp312-cp312-win_amd64.whl (38 kB)
# Using cached yarl-1.18.3-cp312-cp312-win_amd64.whl (90 kB)
# Using cached zc.lockfile-3.0.post1-py3-none-any.whl (9.8 kB)
# Using cached gql-3.5.0-py2.py3-none-any.whl (74 kB)
# Using cached lxml-5.3.0-cp312-cp312-win_amd64.whl (3.8 MB)
# Using cached Mako-1.3.8-py3-none-any.whl (78 kB)
# Using cached aiohappyeyeballs-2.4.4-py3-none-any.whl (14 kB)
# Using cached aiohttp_retry-2.9.1-py3-none-any.whl (10.0 kB)
# Using cached aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Using cached amqp-5.3.1-py3-none-any.whl (50 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached asyncssh-2.19.0-py3-none-any.whl (372 kB)
# Using cached billiard-4.2.1-py3-none-any.whl (86 kB)
# Using cached click_didyoumean-0.3.1-py3-none-any.whl (3.6 kB)
# Using cached click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Using cached click_repl-0.3.0-py3-none-any.whl (10 kB)
# Using cached Deprecated-1.2.15-py2.py3-none-any.whl (9.9 kB)
# Using cached dictdiffer-0.9.0-py2.py3-none-any.whl (16 kB)
# Using cached diskcache-5.6.3-py3-none-any.whl (45 kB)
# Using cached frozenlist-1.5.0-cp312-cp312-win_amd64.whl (51 kB)
# Using cached google_auth-2.37.0-py2.py3-none-any.whl (209 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Using cached jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached multidict-6.1.0-cp312-cp312-win_amd64.whl (28 kB)
# Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Using cached orjson-3.10.12-cp312-none-win_amd64.whl (135 kB)
# Using cached propcache-0.2.1-cp312-cp312-win_amd64.whl (44 kB)
# Using cached pygit2-1.16.0-cp312-cp312-win_amd64.whl (1.3 MB)
# Using cached referencing-0.35.1-py3-none-any.whl (26 kB)
# Using cached rpds_py-0.22.3-cp312-cp312-win_amd64.whl (235 kB)
# Using cached ruamel.yaml.clib-0.2.12-cp312-cp312-win_amd64.whl (115 kB)
# Using cached semver-3.0.2-py3-none-any.whl (17 kB)
# Using cached smmap-5.0.1-py3-none-any.whl (24 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached sqltrie-0.11.1-py3-none-any.whl (17 kB)
# Using cached typer-0.15.1-py3-none-any.whl (44 kB)
# Using cached zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Using cached atpublic-5.0-py3-none-any.whl (5.2 kB)
# Using cached entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Using cached filelock-3.16.1-py3-none-any.whl (16 kB)
# Using cached setuptools-75.6.0-py3-none-any.whl (1.2 MB)
# Using cached cffi-1.17.1-cp312-cp312-win_amd64.whl (181 kB)
# Using cached cryptography-44.0.0-cp39-abi3-win_amd64.whl (3.2 MB)
# Using cached pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Installing collected packages: pytz, pygtrie, funcy, dictdiffer, appdirs, antlr4-python3-runtime, zipp, wrapt, watchdog, waitress, voluptuous, vine, urllib3, tzdata, typing-extensions, treelib, tqdm, tomlkit, toml, threadpoolctl, tenacity, tabulate, sqlparse, sniffio, smmap, shtab, shortuuid, shellingham, setuptools, semver, ruamel.yaml.clib, rpds-py, regex, pyyaml, python-dotenv, pyparsing, pycparser, pyasn1, pyarrow, protobuf, propcache, pillow, pathvalidate, pathspec, orjson, numpy, networkx, narwhals, mypy-extensions, multidict, mdurl, marshmallow, MarkupSafe, markdown, lxml, kiwisolver, joblib, jmespath, itsdangerous, idna, h11, greenlet, graphql-core, fsspec, frozenlist, fonttools, flatten-dict, filelock, entrypoints, dvc-render, dpath, distro, diskcache, dacite, cycler, configobj, cloudpickle, click, charset-normalizer, certifi, cachetools, blinker, billiard, backoff, attrs, atpublic, annotated-types, aioitertools, aiohappyeyeballs, zc.lockfile, yarl, Werkzeug, typing-inspect, sqltrie, sqlalchemy, scipy, ruamel.yaml, rsa, requests, referencing, pydot, pydantic-core, pyasn1-modules, pandas, omegaconf, nltk, markdown-it-py, Mako, Jinja2, importlib_metadata, httpcore, graphql-relay, grandalf, gitdb, flufl.lock, dvc-objects, dulwich, deprecated, contourpy, click-repl, click-plugins, click-didyoumean, cffi, botocore, anyio, amqp, aiosignal, scikit-learn, s3transfer, rich, requests-toolbelt, pygit2, pydeck, pydantic, opentelemetry-api, matplotlib, kombu, jsonschema-specifications, iterative-telemetry, hydra-core, httpx, graphene, gql, google-auth, gitpython, Flask, dvc-studio-client, dvc-data, docker, dataclasses-json, cryptography, alembic, aiohttp, typer, opentelemetry-semantic-conventions, jsonschema, databricks-sdk, dagshub-annotation-converter, celery, boto3, asyncssh, aiohttp-retry, aiobotocore, scmrepo, s3fs, opentelemetry-sdk, dvc-task, dvc-http, dagshub, altair, streamlit, mlflow-skinny, gto, mlflow, dvc, dvc_s3

# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv('dataset/tmdb_5000_movies.csv')
credits = pd.read_csv('dataset/tmdb_5000_credits.csv')

# %%
movies.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500

# %%
credits.head(2)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...

# %%
movies.shape , credits.shape
# Out:
# ((4803, 20), (4803, 4))

# %%
movies = movies.merge(credits,on='title')

# %%
movies.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  ... runtime  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                        tagline   title vote_average vote_count movie_id  \
# 0  Enter the World of Pandora.  Avatar          7.2      11800    19995
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
#
# [1 rows x 23 columns]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4809 non-null   int64
#  1   genres                4809 non-null   object
#  2   homepage              1713 non-null   object
#  3   id                    4809 non-null   int64
#  4   keywords              4809 non-null   object
#  5   original_language     4809 non-null   object
#  6   original_title        4809 non-null   object
#  7   overview              4806 non-null   object
#  8   popularity            4809 non-null   float64
#  9   production_companies  4809 non-null   object
#  10  production_countries  4809 non-null   object
#  11  release_date          4808 non-null   object
#  12  revenue               4809 non-null   int64
#  13  runtime               4807 non-null   float64
#  14  spoken_languages      4809 non-null   object
#  15  status                4809 non-null   object
#  16  tagline               3965 non-null   object
#  17  title                 4809 non-null   object
#  18  vote_average          4809 non-null   float64
#  19  vote_count            4809 non-null   int64
#  20  movie_id              4809 non-null   int64
#  21  cast                  4809 non-null   object
#  22  crew                  4809 non-null   object
# dtypes: float64(3), int64(5), object(15)
# memory usage: 864.2+ KB

# %%
movies['original_language'].value_counts().plot(kind='bar')
# very imbalance data, no use in keeping the column it can rather create issues in the long run!
# Out:
# <Axes: xlabel='original_language'>

# %%
# keeping necessary columns
movies = movies[['movie_id','title','overview','genres','keywords','cast','crew']]
movies.head(1)
# Out:
#    movie_id   title                                           overview  \
# 0     19995  Avatar  In the 22nd century, a paraplegic Marine is di...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
# genre: only genre name
# keywords: only keywords
# cast: top 3 actors
# crew: director

# %%
movies.isnull().sum()
# Out:
# movie_id    0
# title       0
# overview    3
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
movies.dropna(inplace=True)
movies.isnull().sum()
# Out:
# movie_id    0
# title       0
# overview    0
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
movies.iloc[0].genres
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %% [markdown]
# Convert '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]' to ['Action' , 'Adventure' , 'Fantasy' , 'Science Fiction']

# %%
import ast
def fetch_all(obj):
    L = []
    for i in ast.literal_eval(obj):
        L.append(i['name'])
    return L

def fetch_top3_actors(obj):
    L = []
    counter = 0
    for i in ast.literal_eval(obj):
        L.append(i['name'])
        counter += 1
        if counter == 3:
            break
    return L

def fetch_director(obj):
    L = []
    for i in ast.literal_eval(obj):
        if i['job'] == 'Director':
            L.append(i['name'])
            break
    return L

# %%
movies['genres'] = movies['genres'].apply(fetch_all)
movies['keywords'] = movies['keywords'].apply(fetch_all)
movies['cast'] = movies['cast'].apply(fetch_top3_actors)
movies['crew'] = movies['crew'].apply(fetch_director)

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                                cast                 crew
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weaver]      [James Cameron]
# 1     [Johnny Depp, Orlando Bloom, Keira Knightley]     [Gore Verbinski]
# 2      [Daniel Craig, Christoph Waltz, Léa Seydoux]         [Sam Mendes]
# 3      [Christian Bale, Michael Caine, Gary Oldman]  [Christopher Nolan]
# 4    [Taylor Kitsch, Lynn Collins, Samantha Morton]     [Andrew Stanton]

# %%
movies['overview'][0]
# Out:
# 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.'

# %%
movies['overview']= movies['overview'].apply(lambda x:x.split())
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                                cast                 crew
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weaver]      [James Cameron]
# 1     [Johnny Depp, Orlando Bloom, Keira Knightley]     [Gore Verbinski]
# 2      [Daniel Craig, Christoph Waltz, Léa Seydoux]         [Sam Mendes]
# 3      [Christian Bale, Michael Caine, Gary Oldman]  [Christopher Nolan]
# 4    [Taylor Kitsch, Lynn Collins, Samantha Morton]     [Andrew Stanton]

# %% [markdown]
# removing spaces from the names because we are creating tags, and spaces can lead to different tags

# %%
movies['genres'] = movies['genres'].apply(lambda x:[i.replace(" ","") for i in x])
movies['keywords'] = movies['keywords'].apply(lambda x:[i.replace(" ","") for i in x])
movies['cast'] = movies['cast'].apply(lambda x:[i.replace(" ","") for i in x])
movies['crew'] = movies['crew'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3  [dccomics, crimefighter, terrorist, secretiden...
# 4  [basedonnovel, mars, medallion, spacetravel, p...
#
#                                             cast                crew
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver]      [JamesCameron]
# 1     [JohnnyDepp, OrlandoBloom, KeiraKnightley]     [GoreVerbinski]
# 2      [DanielCraig, ChristophWaltz, LéaSeydoux]         [SamMendes]
# 3      [ChristianBale, MichaelCaine, GaryOldman]  [ChristopherNolan]
# 4    [TaylorKitsch, LynnCollins, SamanthaMorton]     [AndrewStanton]

# %%
movies['tags'] = movies['overview']+movies['genres']+movies['keywords']+movies['cast']+movies['crew']
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3  [dccomics, crimefighter, terrorist, secretiden...
# 4  [basedonnovel, mars, medallion, spacetravel, p...
#
#                                             cast                crew  \
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver]      [JamesCameron]
# 1     [JohnnyDepp, OrlandoBloom, KeiraKnightley]     [GoreVerbinski]
# 2      [DanielCraig, ChristophWaltz, LéaSeydoux]         [SamMendes]
# 3      [ChristianBale, MichaelCaine, GaryOldman]  [ChristopherNolan]
# 4    [TaylorKitsch, LynnCollins, SamanthaMorton]     [AndrewStanton]
#
#                                                 tags
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...

# %%
new_df = movies[['movie_id','title','tags']]
new_df['tags'] = new_df['tags'].apply(lambda x:" ".join(x))
# Out:
# C:\Users\bhavy\AppData\Local\Temp\ipykernel_22416\855634588.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x:" ".join(x))

# %%
new_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...

# %%
new_df['tags'][0]
# Out:
# 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization. Action Adventure Fantasy ScienceFiction cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d SamWorthington ZoeSaldana SigourneyWeaver JamesCameron'

# %%
new_df['tags'] = new_df['tags'].apply(lambda x:x.lower())
new_df.head()
# Out:
# C:\Users\bhavy\AppData\Local\Temp\ipykernel_22416\842480936.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x:x.lower())
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  in the 22nd century, a paraplegic marine is di...
# 1  captain barbossa, long believed to be dead, ha...
# 2  a cryptic message from bond’s past sends him o...
# 3  following the death of district attorney harve...
# 4  john carter is a war-weary, former military ca...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
vectors = cv.fit_transform(new_df['tags']).toarray()
vectors[0] # sparse matrix
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(5000,))

# %%
cv.get_feature_names_out()
# Out:
# array(['000', '007', '10', ..., 'zone', 'zoo', 'zooeydeschanel'],
#       shape=(5000,), dtype=object)

# %%
import nltk
from nltk.stem.porter import PorterStemmer
ps= PorterStemmer()

# %%
def stem(text):
    y = []
    for i in text.split():
        y.append(ps.stem(i))
    return " ".join(y)

# %%
new_df['tags'] = new_df['tags'].apply(stem)
new_df['tags']
# Out:
# C:\Users\bhavy\AppData\Local\Temp\ipykernel_22416\4269356531.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(stem)
# 0       in the 22nd century, a parapleg marin is dispa...
# 1       captain barbossa, long believ to be dead, ha c...
# 2       a cryptic messag from bond’ past send him on a...
# 3       follow the death of district attorney harvey d...
# 4       john carter is a war-weary, former militari ca...
#                               ...
# 4804    el mariachi just want to play hi guitar and ca...
# 4805    a newlyw couple' honeymoon is upend by the arr...
# 4806    "signed, sealed, delivered" introduc a dedic q...
# 4807    when ambiti new york attorney sam is sent to s...
# 4808    ever sinc the second grade when he first saw h...
# Name: tags, Length: 4806, dtype: object

# %%
cv.get_feature_names_out()
# Out:
# array(['000', '007', '10', ..., 'zone', 'zoo', 'zooeydeschanel'],
#       shape=(5000,), dtype=object)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vectors)

# %%
similarity[1]
# Out:
# array([0.08740748, 1.        , 0.06451613, ..., 0.02677398, 0.        ,
#        0.        ], shape=(4806,))

# %%
def recommend(movie):
    movie_index = new_df[new_df['title'] == movie].index[0]
    distances = similarity[movie_index]
    movies_list = sorted(list(enumerate(distances)), reverse=True,  key =lambda x:x[1])[1:6]
    for i in movies_list:
       print(new_df.iloc[i[0]].title)

# %%
recommend('Batman Begins')
# Out:
# The Dark Knight
# The Dark Knight Rises
# Batman
# Batman
# Batman & Robin

# %%
import pickle

# %%
pickle.dump(new_df,open('artifacts/movies.pkl','wb'))

# %%
# save new_df as csv file in artifacts
new_df.to_csv('artifacts/movies.csv',index=False)

# %%
pickle.dump(similarity,open('artifacts/similarity.pkl','wb'))
